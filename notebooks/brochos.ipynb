# %% [markdown]
# Brochos
# ---
#
# Storer, pag. 30

# %%
using StringFigures

brochos = proc"OA::1o(2f)#2o(u1n):2u(l1f)#D1|1o(l2f):1u(5f)#D5|5o(u2n)#Du2|"
# Out:
# StringProcedure(L1:x1(0):R2:x2(0):L5:R5:x2(U):L2:x1(U):R1, calc"1o(2f) # 2o(u1n):2u(l1f) # D1 # | # 1o(l2f):1u(5f) # D5 # | # 5o(u2n) # Du2 # |")

# %%
#plot(brochos; shadowc="white", stringc="black", nodelabelc="black", background_color="white")
plot(brochos)
# Out:
# StringFigures.IndexedProcedure(StringProcedure(L1:x1(0):R2:x2(0):L5:R5:x2(U):L2:x1(U):R1, calc"1o(2f) # 2o(u1n):2u(l1f) # D1 # | # 1o(l2f):1u(5f) # D5 # | # 5o(u2n) # Du2 # |"), 0)
# ...
