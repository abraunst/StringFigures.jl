# %%
using StringFigures

# %%
osage2diam = seq"L1: x1(0): x2(U): x3(0): x4(0): x5(U): x6(0): x7(0): x8(U): x9(U): x10(0): x11(U): x12(U): R2: x12(0): x13(U): x14(0): x5(0): x4(U): x15(0): L2: x15(U): x3(U): x2(0): x1(U): x16(U): x17(0): x6(U): x14(U): x13(0): x11(0): x10(U): x9(0): R1: x8(0): x7(U): x17(U): x16(0)"
# Out:
# seq"L1:x1(0):x2(U):x3(0):x4(0):x5(U):x6(0):x7(0):x8(U):x9(U):x10(0):x11(U):x12(U):R2:x12(0):x13(U):x14(0):x5(0):x4(U):x15(0):L2:x15(U):x3(U):x2(0):x1(U):x16(U):x17(0):x6(U):x14(U):x13(0):x11(0):x10(U):x9(0):R1:x8(0):x7(U):x17(U):x16(0)"

# %%
plot(osage2diam)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7479283402821769cx, 0.995449370811245cy), (-0.7060409899730472cx, 0.903439183367611cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7451405933307779cx, 0.9988226441391325cy
# ...

# %%
isfarsidenext(osage2diam, node"L1")
# Out:
# true

# %%
canonical(osage2diam).seq == osage2diam.seq
# Out:
# true

# %%
osage1diam = seq"L1: x1(U): x2(0): x3(U): x1(0): x4(0): x5(U): x6(U): x7(0): x8(U): x9(U): R2: x9(0): x10(U): x11(0): x12(0): L2: x12(U): x3(0): x2(U): xll (U): x10(0): x8 (0): x7(U): x6 (0): Rl: x5(0): x4 (U)"
plot(osage1diam)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7459678739382941cx, 0.997043319526477cy), (-0.636383708960863cx, 0.9166873594603322cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7450118288550467cx, 0.9996562724499626cy
# ...

# %%
OA = seq"Ll: x1(0): R3: x2(0): L5: R5: x2(U): L3: xl(U): Rl"
plot(OA)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7466734184855987cx, 0.9959185766793041cy), (-0.37841126050346663cx, 0.5826859783759617cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7450000005431356cx, 0.9996537151880385cy), (-0.0020676825350918193cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{
# ...

# %%
pick(true, OA, node"L2", node"L5", false) |> simplify |> plot
# Out:
# "in arg" = "in arg"
# ...

# %%
p = seq"Ll: x1(0): R2: x2(0): L5: R5: x2(U): L2: xl(U): x3(U): Rl: x3(0)"
# Out:
# seq"L1:x1(0):R2:x2(0):L5:R5:x2(U):L2:x1(U):x3(U):R1:x3(0)"

# %%
release(p, node"L1")
# Out:
# seq"L2:x1(U):R5:L5:x1(0):R2:x2(0):x3(0):R1:x3(U):x2(U)"

# %%
# Double Brochol, Storer, page 39
doublebrochol = seq"Ll: x1(0): x2(U): x3(0): x4(U): x5(0): x6(0): x7(0): x8(0): x9(0): xlO(U): xll(U): x12(0): xl3(0): x14(U): xlS(U): x7(U): xl6(0): x17(U): xl8(0): x19(U): X2(0): x20(U): LS: X21(U): x22(0): X4(0): xS(U): x23(U): x24(0): x14(0): x13(U): RS: x12(U): x25(0): x8(U): x26(0): x27(U): x16(U): x28(U): x3(U): x22(U); x21(0): x20(0): xl(U): x29(U): x30(0): x19(0): x28(0): x6(U): x23(0): x24(U): x15(0): x25(U): X11(0): Rl: x10(0): X9(U): x26(U): x27(0): x17(0): x18(U): x30(U): x29(0)"
# Out:
# seq"L1:x1(0):x2(U):x3(0):x4(U):x5(0):x6(0):x7(0):x8(0):x9(0):x10(U):x11(U):x12(0):x13(0):x14(U):x15(U):x7(U):x16(0):x17(U):x18(0):x19(U):x2(0):x20(U):L5:x21(U):x22(0):x4(0):x5(U):x23(U):x24(0):x14(0):x13(U):R5:x12(U):x25(0):x8(U):x26(0):x27(U):x16(U):x28(U):x3(U):x22(U):x21(0):x20(0):x1(U):x29(U):x30(0):x19(0):x28(0):x6(U):x23(0):x24(U):x15(0):x25(U):x11(0):R1:x10(0):x9(U):x26(U):x27(0):x17(0):x18(U):x30(U):x29(0)"

# %%
plot(doublebrochol)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7498379934903266cx, 0.9950026253001377cy), (-0.739214360919028cx, 0.6672980612090289cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7488083736299896cx, 0.995144073044794cy
# ...

# %%
db2 = release(doublebrochol, node"R5")
# Out:
# seq"L1:x1(0):x2(U):x3(0):x4(U):x5(0):x6(0):x7(0):x8(0):x9(0):x10(U):x11(U):x12(0):x13(0):x14(U):x15(U):x7(U):x16(0):x17(U):x18(0):x19(U):x2(0):x20(U):L5:x21(U):x22(0):x4(0):x5(U):x23(U):x24(0):x14(0):x13(U):x12(U):x25(0):x8(U):x26(0):x27(U):x16(U):x28(U):x3(U):x22(U):x21(0):x20(0):x1(U):x29(U):x30(0):x19(0):x28(0):x6(U):x23(0):x24(U):x15(0):x25(U):x11(0):R1:x10(0):x9(U):x26(U):x27(0):x17(0):x18(U):x30(U):x29(0)"

# %%
plot(db2)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7498741655131865cx, 0.97487917337695cy), (-0.7425981117563797cx, 0.6858586771266673cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7483464380350089cx, 0.9751589317465802cy
# ...

# %%
simplify(db2) |> plot
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7498087472425654cx, 0.98758018942535cy), (-0.7360225420332156cx, 0.6274254818090199cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7489428055074276cx, 0.9876895742368449cy
# ...

# %%
test |> plot
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7465499155832473cx, 0.9963810336396589cy), (-0.43996298972534664cx, 0.6747866500899231cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.745033352020317cx, 0.9994234517835338
# ...

# %%
test1 = release(test, node"L5")
# Out:
# seq"L1:x1(0):R2:x2(0):R5:x2(U):L2:x1(U):x3(U):R1:x3(0)"

# %%
test2 = release(test1, node"R5")
plot(test2)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7465625037807757cx, 0.9963690745335633cy), (-0.4422305052349038cx, 0.6749121962417304cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.745027242228211cx, 0.9994787705465801c
# ...

# %%
test3 = canonical(test2)
# Out:
# seq"L1:x1(0):R2:x2(0):x2(U):L2:x1(U):x3(U):R1:x3(0)"

# %%
test4 = simplify(test3)
# Out:
# seq"L1:x1(0):R2:L2:x1(U):x2(U):R1:x2(0)"

# %%
plot(test4)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7465111730637488cx, 0.9964183681639666cy), (-0.4259301048775098cx, 0.6673096502981317cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7450290263903413cx, 0.9994620210300792
# ...

# %%
# Example in Fig. 10, pag 12
p = seq"L1:L5:x1(0):x2(0):x2(U):x3(0):R5:R1:x3(U):x1(U)"
# Out:
# seq"L1:L5:x1(0):x2(0):x2(U):x3(0):R5:R1:x3(U):x1(U)"

# %%
p |> plot
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7500009501321128cx, 0.9950000000902751cy), (-0.750188441211353cx, 0.008342074592997406cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7479876768187216cx, 0.995422822330945
# ...

# %%
p2 = simplify(p)
# Out:
# seq"L1:L5:R5:R1"

# %%
plot(p2)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7499999179484002cx, 0.9948657842229603cy), (-0.7499833285425503cx, -0.01604721917015972cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7450000000784448cx, 0.9998666699128095cy), (0.0076900295015653874cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{
# ...

# %%
pick(true, p2, node"R2", node"R5", true) |> plot
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7499995185927081cx, 0.9948603836654935cy), (-0.7499037977439789cx, 0.0006830011130114499cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.745000000086848cx, 0.9998613155646388cy), (-0.0009227852730339103cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple
# ...

# %%
test |> plot
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7465522218437121cx, 0.9963788364045485cy), (-0.4362863534065493cx, 0.6705099965991901cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7450331299672184cx, 0.9994253678764153cy), (-0.3190992903536173cx, 0.950147801693219cy)]), Compose.LinePrimitive{Tuple{Measure, Measur
# ...

# %%
p2 |> plot
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7499999078349289cx, 0.9948653217050127cy), (-0.7499816172743634cx, 0.002593502395366487cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7450000000822002cx, 0.99986622834777
# ...

# %%
p3 = pick(true, p2, node"L2", node"L5", false) 
p3 |> plot
# Out:
# "in arg" = "in arg"
# adding pair SeqNode[node"x2(U)", node"x1(U)"] at pos 3(node"R5")
# ...

# %%
p3
# Out:
# seq"L1:x1(0):L2:x2(0):L5:x2(U):x1(U):R5:R1"

# %%
p4 = pick(true, p3, node"L3", node"L5", true)
# Out:
# seq"L1:x1(0):L2:x2(0):L3:L5:x2(U):x1(U):R5:R1"

# %%
plot(p4)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7480581644303307cx, 0.9951172026422432cy), (-0.5107503722706281cx, 0.43204106324749736cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7450000003358496cx, 0.999726558959369
# ...

# %%
fig155b = canonical(seq"Ll: x9(0): x7(0): x5(0): x3(0): LS: RS: x2(U): x4(U): x3(U): L3: xS(U): x6(U): xl(U): R2: xlO(U): x9(U): L2: x7(U): x8(U): x1(0): R3: x2(0): x4(0): x6(0): x8(0): x1O(0)")
fig155a = seq"L2: x1(0): R3: x2(0): L5: RS: x2(U): L3: xl(U): R2"
# Out:
# seq"L2:x1(0):R3:x2(0):L5:R5:x2(U):L3:x1(U):R2"

# %%
plot(fig155a)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.9951388698089167cx, -0.0009534824825385654cy), (-0.4892604545378322cx, -0.12273353643601304cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.9950000002513cx, 0.0002183220853
# ...

# %%
fig155a
# Out:
# seq"L2:x1(0):R3:x2(0):L5:R5:x2(U):L3:x1(U):R2"

# %%
fa = pick(true, fig155a, node"R4", node"R2", false)
# Out:
# seq"L2:x1(0):x3(U):x4(U):R3:x6(U):x5(U):x2(0):L5:R5:x2(U):L3:x1(U):x3(0):x5(0):R4:x6(0):x4(0):R2"

# %%
plot(fa)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9957034860653986cx, -0.002557336115917493cy), (-0.7463636454344652cx, -0.15096737022459394cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9950000006238435cx, 2.4976857990134933e-6cy), (-0.0023703819752972644cx, 0.0004983531281019804cy)]), Compose.LinePrimitive{Tuple{
# ...

# %%
fb = pick(true, fig155a, node"L1", node"L5", true)
# Out:
# seq"x9(U):x10(U):L2:x8(U):x7(U):x1(0):R3:x2(0):x3(0):x5(0):x7(0):x9(0):L1:x10(0):x8(0):x6(0):x4(0):L5:R5:x2(U):x3(U):x4(U):L3:x6(U):x5(U):x1(U):R2"

# %%
replace("x9(U):x10(U):L2:x8(U):x7(U):x1(0):R3:x2(0):x3(0):x5(0):x7(0):x9(0):L1:x10(0):x8(0):x6(0):x4(0):L5:R5:x2(U):x3(U):x4(U):L3:x6(U):x5(U):x1(U):R2", "L"=>"R", "R"=>"L")
# Out:
# "x9(U):x10(U):R2:x8(U):x7(U):x1(0):L3:x2(0):x3(0):x5(0):x7(0):x9(0):R1:x10(0):x8(0):x6(0):x4(0):R5:L5:x2(U):x3(U):x4(U):R3:x6(U):x5(U):x1(U):L2"

# %%
fc = seq"x9(U):x10(U):R2:x8(U):x7(U):x1(0):L3:x2(0):x3(0):x5(0):x7(0):x9(0):R1:x10(0):x8(0):x6(0):x4(0):R5:L5:x2(U):x3(U):x4(U):R3:x6(U):x5(U):x1(U):L2"
# Out:
# seq"x9(U):x10(U):R2:x8(U):x7(U):x1(0):L3:x2(0):x3(0):x5(0):x7(0):x9(0):R1:x10(0):x8(0):x6(0):x4(0):R5:L5:x2(U):x3(U):x4(U):R3:x6(U):x5(U):x1(U):L2"

# %%
canonical(fa)
# Out:
# seq"L2:x1(0):x2(U):x3(U):R3:x4(U):x5(U):x6(0):L5:R5:x7(0):x8(0):x4(0):x3(0):R1:x2(0):x5(0):x9(0):x10(0):x6(U):L3:x1(U):x10(U):x7(U):R2:x8(U):x9(U)"

# %%
canonical(fc)
# Out:
# seq"L2:x1(U):x2(U):x3(U):R3:x4(U):x5(U):x6(U):L5:R5:x4(0):x3(0):x7(0):x8(0):R1:x9(0):x10(0):x2(0):x5(0):x6(0):L3:x1(0):x10(U):x7(U):R2:x8(U):x9(U)"

# %%
plot(fig155picked)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9953702486036202cx, 0.002064411170816357cy), (-0.525983689548606cx, 0.19350200647950166cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9952681038432387cx, -0.0014391051065498978cy), (-0.772184272507974cx, -0.07759142571260547cy)]), Compose.LinePrimitive{Tuple{Measure
# ...

# %%
fig155b == fig155picked
# Out:
# true

# %%
simplify(fig155picked) |> plot
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7483201037798576cx, 0.9952906530506289cy), (-0.6347780741918816cx, 0.6769919365857486cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7460414945536964cx, 0.996945456722915c
# ...

# %%
fig156a = seq"Ll: xl (0): x2 (0): x3 (0): R3: x4 (0): xS (0): x6 (0): LS: x6 (U): x7 (U): 
xB(U): x9(0): x4(U): xlO(U): RS: x1O(0): xS(U): x7(0): L3: xl(U): 
xll (0): xl2 (0) : Rl: x12 (U): x3 (U) : x9 (U): x8 (0): x2 (U): xll (U)"
# Out:
# seq"L1:x1(0):x2(0):x3(0):R3:x4(0):x5(0):x6(0):L5:x6(U):x7(U):x8(U):x9(0):x4(U):x10(U):R5:x10(0):x5(U):x7(0):L3:x1(U):x11(0):x12(0):R1:x12(U):x3(U):x9(U):x8(0):x2(U):x11(U)"

# %%
plot(fig156a)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7486043689917943cx, 0.9951987278676444cy), (-0.636294054584046cx, 0.6088269866469771cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7459516044919741cx, 0.9970656357058819cy), (-0.4746278181114536cx, 0.8004043091824384cy)]), Compose.LinePrimitive{Tuple{Measure, Measur
# ...

# %%
res = fig156a |>
    x->pick(true, x, node"R2", node"R1", true) |> 
    x->release(x, node"R1") |> 
    simplify |>
    x->pick(true, x, node"L2", node"L1", true) |> 
    x->release(x, node"L1") |>
    simplify
# Out:
# seq"L2:x1(U):x2(0):x3(0):x4(0):R3:x5(0):x6(0):x7(0):L5:x7(U):x8(U):x9(U):x10(0):x5(U):x11(U):R5:x11(0):x6(U):x8(0):L3:x2(U):x12(0):x13(0):x14(U):R2:x14(0):x13(U):x4(U):x10(U):x9(0):x3(U):x12(U):x1(0)"

# %%
plot(fig156a)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7488253568769048cx, 0.9951399368796934cy), (-0.6560351211505512cx, 0.611222137752848cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.746065465642046cx, 0.9969146411252369cy), (-0.5127834428364236cx, 0.8139809839490182cy)]), Compose.LinePrimitive{Tuple{Measure, Measure
# ...

# %%
fig156apicked = pick(true, fig156a, node"L2", node"R5", true)
# Out:
# seq"L1:x1(U):x2(U):x3(0):x4(0):x5(0):x6(U):x7(U):R3:x8(U):x9(U):x10(0):x11(0):x12(0):L5:x12(U):x13(U):x14(U):x15(0):x10(U):x16(U):R5:x8(0):x7(0):x17(0):x18(0):x19(U):x20(U):x20(0):x21(0):x1(0):L2:x2(0):x22(0):x19(0):x23(0):x24(0):x6(0):x9(0):x16(0):x11(U):x13(0):L3:x3(U):x25(0):x26(0):x24(U):x17(U):R1:x18(U):x23(U):x26(U):x5(U):x15(U):x14(0):x4(U):x25(U):x22(U):x21(U)"

# %%
plot(fig156apicked |> simplify)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7501964485092564cx, 0.9950038606921733cy), (-0.7594736537398533cx, 0.7590631050468106cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7463899436377333cx, 0.9965405935391664cy), (-0.603359911525381cx, 0.8594792937892559cy)]), Compose.LinePrimitive{Tuple{Measure, Measur
# ...
