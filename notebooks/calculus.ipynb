# %%
using StringFigures

fig29VI = proc"OA::DL1#DR1|L1u(L5f)#R1u(R5f)#L1o(L2f)#R1o(R2f)#DL5#DR5|L5o(L1f)#R5o(R1f)#";

# %%
plot(fig29VI)
# Out:
# StringProcedure(seq"L1:x1(0):R2:x2(0):L5:R5:x2(U):L2:x1(U):R1", calc"DL1 # DR1 # | # L1u(L5f) # R1u(R5f) # L1o(L2f) # R1o(R2f) # DL5 # DR5 # | # L5o(L1f) # R5o(R1f)")
# ...
